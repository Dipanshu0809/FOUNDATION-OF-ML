# %%
import numpy as np

# %% [markdown]
# Printing an array

# %%
# import numpy as np
arr = np.array([1,2,3,4,5])
print(arr)
print(type(arr))

# %% [markdown]
# Printing 2d array

# %%
arr1 = np.array([[1,2,3],[5,6,7],[2,0,8]])
print(arr1)

# %% [markdown]
# Predefined functions

# %%
np.zeros(4)

# %%
np.ones(5)

# %%
np.zeros((3,6))

# %%
np.ones((3,4))

# %% [markdown]
# Range

# %%
np.arange(2,10)

# %%
np.arange(1,12,3)

# %% [markdown]
# Dividing into equal subparts

# %%
np.linspace(0,1,5)

# %%
np.linspace(2,8,16)

# %%
arr= np.array([[1,3,4,5],[4,5,8,9],[3,5,8,6]])

# %%
print(arr.ndim) #dimension 
print(arr.shape)
print(arr.size)
print(arr.dtype)

# %% [markdown]
# Type Conversion

# %%
arr2 = np.array([1.2, 3.4, 5.6])
arr_int = arr.astype(int)
print(arr_int)

# %% [markdown]
# Indexing & Sciling

# %%
arr = np.array([10,20,30,40])
print(arr[0])
print(arr[-1])

# %% [markdown]
# 1D slicing

# %%
print(arr[1:3])
print(arr[:3])
print(arr[::2])

# %% [markdown]
# Sum of arrays

# %%
a = ([1,2,3,4],[8,6,7,9])
b= ([2,4,1,5],[6,5,3,7])
Sum = np.add(a,b)
print(Sum)

# %% [markdown]
# Adding elements of array

# %%
Sum = np.sum(a)
print(Sum)

# %% [markdown]
# 2D indexing

# %%
mat = np.array([[1,2,4],[2,4,5],[3,5,6]])
print(mat[2,2])
print(mat[1])

# %%
print(mat[:,1])

# %% [markdown]
# Updating and changing the array using copy

# %%
a= np.array([1,2,3])
b=a.copy()
b[2]=99
print(a)
print(b)

# %% [markdown]
# Updating the array (not safe as original array is changed)

# %%
a = np.array([1,2,3,4])
b = a
b[0] = 99
print(a)

# %% [markdown]
# Basic Array Operations (Vector Power)

# %%
a = np.array([1,3,4])
b = np.array([8,9,3])

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)

# %% [markdown]
# Scalar Operations

# %%
print(a+10)
print(a*2)

# %% [markdown]
# Universal functions (unfus)

# %%
arr = np.array([1,3,4,5,6])
print(np.sqrt(arr))
print(np.log(arr))
print(np.exp(arr))
print(np.max(arr))
print(np.min(arr))
print(np.mean(arr))
print(np.sum(arr))
print(np.std(arr))

# %% [markdown]
# Boolean indexing

# %%
arr = np.array([10,20,30,40,50])
print(arr[arr>29])

# %%
print(arr>29)

# %% [markdown]
# Broadcasting Rule

# %%
# Numpy automatically expands arrays
arr = np.array([1,2,3,4])
print(arr+10)

# %%
mat = np.array([[1,2,3],[4,5,6]])
print(mat+10)

# %% [markdown]
# Matrix Multiplication

# %%
A = np.array([[1,2],[3,4]])
B= np.array([[5,6],[7,8]])
print(np.dot(A,B))

# %%
print(A.T) #transpose

# %% [markdown]
# Random Module

# %%
np.random.rand(5) #used to generate random int

# %%
np.random.rand(3,3)

# %%
np.random.randint(1,100,10) #random number with 10 no. of integers

# %% [markdown]
# Reshaping Arrays

# %%
arr = np.arange(16)
print(arr.reshape(4,4))

# %% [markdown]
# axis in NumPy

# %%
arr = np.array([[1,2,3],[7,8,0]])
print(np.sum(arr))

# %%
print(np.sum(arr, axis=0)) #column wise

# %%
print(np.sum(arr, axis = 1)) #row-wise

# %% [markdown]
# Where in numpy

# %%
arr = np.array([10,-3,4,0, 6,-9])
result = np.where(arr< 0, 0 , arr) #if condition true then zero, else output the array as it is
print(result)

# %%
arr= np.array([1,2,3,5,6])
result = np.where(arr % 2 != 0, -1, arr)
print(result)

# %%
marks = np.array([23,45,67, 30, 87])
status = np.where(marks>50, 1, 0)
print(status)

# %%
data = np.array([10,20,50,70,70])
mean_val = np.mean(data)
result = np.where(data > mean_val, mean_val, data)
print(result)

# %%
mat = np.array([[10,80,30],[40,50,60]])
result= np.where(mat > 50, 1, 0)
print(result)

# %% [markdown]
# Create a Numpy array electricity using numpy.random.randint
# values bw 120 and 650
# shape(4,7)

# %%
electricity = np.random.randint(120,650,)
print(electricity)

# %% [markdown]
# shape, no of dimensions,

# %% [markdown]
# Task B1
# find the avg electricity usage per hostel, the maximum usage per hostel, and identify which hostel has the highest average usage

# %% [markdown]
# Calculate the total electricity consumption per day and identify the day with the highest total campus consumption

# %%
total_consumption =

# %% [markdown]
# Students must choose the correct axis values for each operation
